# %% [markdown]
# <a href="https://colab.research.google.com/github/domeano/Thermo-and-Fluid-Engineering-Lab/blob/master/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def Hyperbolic_Next_Step(U, CFL=1.0):
    PI = math.pi
    dx = 5.0
    dt = 0.02
    end_t = 1.0
    L = 400
    alpha = 250.0
    N = int(float(L)/dx)
    iter = int(end_t/dt)
    iter = 50
    
    #################### TO DO #######################


    ##################################################

# %%
def Initial_Condition():
    PI = math.pi
    dx = 5.0
    L = 400
    N = int(float(L)/dx)
    U = np.zeros((N))
    for i in range(int(50.0/dx) , int(110.0/dx+1)):
        U[i] = abs(100.0 * (math.sin(PI*(i*dx - 50.0)/60.0)))
    return U

U = Initial_Condition()
Hyperbolic_Next_Step(U, CFL=0.5)
